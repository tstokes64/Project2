# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
#I used Securities.csv & Fundamentals.csv because the both have a common primary key... "Ticker symbol".

csv_file = "securities.csv"
securities = pd.read_csv(csv_file)
securities.head()
# Out:
#   Ticker symbol             Security SEC filings             GICS Sector  \
# 0           MMM           3M Company     reports             Industrials
# 1           ABT  Abbott Laboratories     reports             Health Care
# 2          ABBV               AbbVie     reports             Health Care
# 3           ACN        Accenture plc     reports  Information Technology
# 4          ATVI  Activision Blizzard     reports  Information Technology
#
#                 GICS Sub Industry   Address of Headquarters Date first added  \
# 0        Industrial Conglomerates       St. Paul, Minnesota              NaN
# 1           Health Care Equipment   North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals   North Chicago, Illinois       2012-12-31
# 3  IT Consulting & Other Services           Dublin, Ireland       2011-07-06
# 4     Home Entertainment Software  Santa Monica, California       2015-08-31
#
#        CIK
# 0    66740
# 1     1800
# 2  1551152
# 3  1467373
# 4   718877

# %%
#I used Securities.csv & Fundamentals.csv because the both have a common primary key... "Ticker symbol".

csv_file = "fundamentals.csv"
Fund_Stock = pd.read_csv(csv_file)
Fund_Stock.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# 2         -5.311000e+09     1.513500e+10        60.0  ...
# 3         -6.151000e+09     1.159100e+10        51.0  ...
# 4         -2.711820e+08     5.202150e+08        23.0  ...
#
#    Total Current Assets  Total Current Liabilities  Total Equity  \
# 0          7.072000e+09               9.011000e+09 -7.987000e+09
# 1          1.432300e+10               1.380600e+10 -2.731000e+09
# 2          1.175000e+10               1.340400e+10  2.021000e+09
# 3          9.985000e+09               1.360500e+10  5.635000e+09
# 4          3.184200e+09               2.559638e+09  1.210694e+09
#
#    Total Liabilities  Total Liabilities & Equity  Total Revenue  \
# 0       2.489100e+10                1.690400e+10   2.485500e+10
# 1       4.500900e+10                4.227800e+10   2.674300e+10
# 2       4.120400e+10                4.322500e+10   4.265000e+10
# 3       4.278000e+10                4.841500e+10   4.099000e+10
# 4       3.403120e+09                4.613814e+09   6.205003e+09
#
#    Treasury Stock  For Year  Earnings Per Share  Estimated Shares Outstanding
# 0    -367000000.0    2012.0               -5.60                  3.350000e+08
# 1             0.0    2013.0              -11.25                  1.630222e+08
# 2             0.0    2014.0                4.02                  7.169154e+08
# 3             0.0    2015.0               11.39                  6.681299e+08
# 4     -27095000.0    2012.0                5.29                  7.328355e+07
#
# [5 rows x 79 columns]

# %% [markdown]
# ### Create new data with select columns

# %%
#Dropping all other columns and only using these three criteria (Maybe we could use a filter to show which companies have the most equity?)
#I also Added "Cash Ratio". Company's that has 1 Cash Ratio should be able to pay off thier Liabilitys with the cash reserves. (IE.)
# There Might be a coorolation between "Cash Ratio's" and "Total Equity"



# Dataframe 1
securities_DF_Cleaned = securities[['Ticker symbol', 'Security', 'GICS Sector']].copy()
securities_DF_Cleaned.head()

# Dataframe 2
Fund_Stock_DF_Cleaned = Fund_Stock[['Ticker Symbol', 'Period Ending', 'Total Equity', 'Cash Ratio']].copy()
Fund_Stock_Exchange.head()
# Out:
#   Ticker Symbol Period Ending  Total Equity  Cash Ratio
# 0           AAL    2012-12-31 -7.987000e+09        53.0
# 1           AAL    2013-12-31 -2.731000e+09        75.0
# 2           AAL    2014-12-31  2.021000e+09        60.0
# 3           AAL    2015-12-31  5.635000e+09        51.0
# 4           AAP    2012-12-29  1.210694e+09        23.0

# %% [markdown]
# ### Connect to local database

# %%
# 1.) You first need to create a dataframe within your local SQL enviroment (TIP: To make it easier name the DF in SQL "NYSE")
# 2.) This Code Pushes Fund_Stock_DF_Cleaned Dataframe into SQL.
# 3.) Also, Please make sure you Change (password="Google123") to your password.
# 4.) Everything else should work Minus the Primary Key... For some reason when I update as ("Ticker Symbol" text PRIMARY KEY,) It fails out.


import psycopg2 as pg2
try:
    conn = pg2.connect(dbname="NYSE", user="postgres", password="Google123")
    cur = conn.cursor()
    cur.execute("""
    CREATE TABLE "securities_DF_Cleaned"(
    id integer PRIMARY KEY,
    Security text,
    "Total Equity" text);
    """)
    conn.commit()
except:
    print("Unable to Connect")

# %%
# 1.) This Code Pushes Fund_Stock_DF_Cleaned Dataframe into SQL.
# 2.) Also, Please make sure you Change (password="Google123") to your password.
# 3.) Everything else should work Minus the Primary Key... For some reason when I use (id integer PRIMARY KEY,) the Table is created.



'Ticker Symbol', 'Period Ending', 'Total Equity', 'Cash Ratio'
import psycopg2 as pg2
try:
    conn = pg2.connect(dbname="NYSE", user="postgres", password="Google123")
    cur = conn.cursor()
    cur.execute("""
    CREATE TABLE "Fund_Stock_DF_Cleaned"(
    "Ticker Symbol" text PRIMARY KEY,
    "Period Ending" text,
    "Total Equity" text,
    "Cash Ratio" text);
    """)
    conn.commit()
except:
    print("Unable to Connect")
# Out:
# Unable to Connect

# %%
rds_connection_string = "postgres:Google123@localhost:5432/NYSE"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()
# Out:
# ['TableETL']

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_customer_location_df.to_sql(name="TableETL", con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
# new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from "TableETL"', con=engine).head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from "TableETL"', con=engine).head()
# Out:
#    id                address  us_state
# 0   1  043 Mockingbird Place   Indiana
# 1   2       4 Prentice Point   Indiana
# 2   3      46 Derek Junction     Texas
# 3   4  11966 Old Shore Place  Missouri
# 4   5     5 Evergreen Circle  New York
